# %% [markdown]
# ## Árvores de regressão - exercícios 02
#
# Este exercício será uma continuação do anterior, mesma base, mesmas variáveis - vamos tentar buscar a 'melhor árvore'.
#
# A descrição das variáveis está abaixo:

# %% [markdown]
# | Variavel | Descrição|
# |-|-|
# |CRIM| taxa de crimes per-cápita da cidade |
# |ZN| proporção de terrenos residenciais zoneados para lotes com mais de 25.000 pés quadrados. |
# |INDUS| proporção de acres de negócios não varejistas por cidade |
# |CHAS |vale 1 se o terreno faz fronteira com o *Charles River*; 0 caso contrário |
# |NOX| Concentração de óxido nítrico (em partes por 10 milhões) |
# |RM| número médio de quartos por habitação |
# |AGE| proporção de unidades ocupadas pelo proprietário construídas antes de 1940 |
# |DIS| distâncias ponderadas até cinco centros de empregos de Boston |
# |RAD| índice de acessibilidade a rodovias radiais |
# |TAX| taxa de imposto sobre a propriedade de valor total por \\$10,000 |
# |PTRATIO| razão pupilo-professor da cidade |
# |B| $ 1000 (Bk - 0,63) ^ 2 $ onde Bk é a proporção de negros por cidade |
# |LSTAT| \%status inferior da população |
# |MEDV| (variável resposta) Valor mediano das casas ocupadas pelo proprietário em US $ 1.000|

# %%
import pandas as pd

import seaborn as sns

from sklearn import datasets
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_squared_error


import matplotlib.pyplot as plt

boston = datasets.load_boston()
X = pd.DataFrame(boston.data, columns = boston.feature_names)
y = pd.DataFrame(boston.target, columns = ['MEDV'])
# Out:
# C:\Users\franz\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
#     Alternative datasets include the California housing dataset (i.e.
#     :func:`~sklearn.datasets.fetch_california_housing`) and the Ames housing
#     dataset. You can load the datasets as follows::
#
#         from sklearn.datasets import fetch_california_housing
#         housing = fetch_california_housing()
#
#     for the California housing dataset and::
#
#         from sklearn.datasets import fetch_openml
#         housing = fetch_openml(name="house_prices", as_frame=True)
#
#     for the Ames housing dataset.
#
#   warnings.warn(msg, category=FutureWarning)

# %%
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
y.head()
# Out:
#    MEDV
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %% [markdown]
# ### 1. Execute os passos do exercício anterior, até que você tenha uma árvore de regressão predizendo o valor do imóvel na base de treinamento.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 2360873)

# %%
regr1 = DecisionTreeRegressor(max_depth = 8)
regr2 = DecisionTreeRegressor(max_depth = 2)

regr1.fit(X_train, y_train)
regr2.fit(X_train, y_train)

mse1 = regr1.score(X_train, y_train)
mse2 = regr2.score(X_train, y_train)

template = 'O R-quadrado da árvore com profundidade = {0} é: {1:.2f}'

print(template.format(regr1.get_depth(),mse1).replace(".",","))
print(template.format(regr2.get_depth(),mse2).replace(".",","))

mse1 = mean_squared_error(y_test, regr1.predict(X_test))
mse2 = mean_squared_error(y_test, regr2.predict(X_test))

template = 'O MSE da árvore com profundidade = {0} é: {1:.2f}'

print(template.format(regr1.get_depth(),mse1).replace(".",","))
print(template.format(regr2.get_depth(),mse2).replace(".",","))
# Out:
# O R-quadrado da árvore com profundidade = 8 é: 0,98
# O R-quadrado da árvore com profundidade = 2 é: 0,71
# O MSE da árvore com profundidade = 8 é: 25,99
# O MSE da árvore com profundidade = 2 é: 26,46

# %% [markdown]
# ### 2.  Calcule o caminho indicado pelos CCP-alfas dessa árvore.

# %%
path = regr1.cost_complexity_pruning_path(X_train, y_train)

path
# Out:
# {'ccp_alphas': array([0.00000000e+00, 2.39972217e-15, 1.31926121e-05, 1.18733509e-04,
#         2.11081794e-04, 3.29815303e-04, 3.29815303e-04, 3.29815303e-04,
#         5.32102023e-04, 6.46437995e-04, 7.43183817e-04, 8.44327177e-04,
#          5.8126627 ,  6.12928539,  6.45832013,  7.21543333,  7.65904487,
#          8.16154536,  8.70886734,  9.25753572,  9.823506  , 10.48541868,
#         11.21464756, 11.95478297, 12.83148592, 13.79799647, 15.35045149,
#         18.13101449, 21.18811969, 25.84925111, 31.13095486, 48.19156561,
#         89.86342242])}

# %%
ccp_alphas, impurities = path.ccp_alphas, path.impurities

plt.figure(figsize = (10, 6))
plt.plot(ccp_alphas, impurities)
plt.xlabel("Alpha efetivo")
plt.ylabel("Impureza total das folhas")
# Out:
# Text(0, 0.5, 'Impureza total das folhas')

# %% [markdown]
# ### 3. Paca cada valor de alpha obtido no item 2, treine uma árvore com o respectivo alfa, e guarde essa árvore em uma lista.

# %%
clfs = []

for ccp_alpha in ccp_alphas:
    clf = DecisionTreeRegressor(random_state = 0, ccp_alpha = ccp_alpha)
    clf.fit(X_train, y_train)
    clfs.append(clf)

# %%
clfs
# Out:
# [DecisionTreeRegressor(random_state=0),
#  DecisionTreeRegressor(ccp_alpha=2.3997221682663013e-15, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=1.3192612137191168e-05, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.00011873350923682026, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.00021108179419685846, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0003298153034252797, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.00032981530342992914, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0003298153034302666, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0005321020228674603, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0006464379947226672, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.000743183817062969, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0008443271767814345, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0008619173262994893, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0013192612137204666, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0013192612137209166, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0015963060686015936, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0019393139841675142, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0019428320140664232, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0025417766051016814, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.002585751978891831, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0025857519788924687, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.002968337730870712, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0033773087071237886, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0034476693051982573, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0037401055408971453, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.004762532981530511, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.005573878627972267, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.006058927000881016, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.006350043975374089, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.007143799472295467, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.007392260334214818, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.00744415127528399, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.009046362608364028, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.009696569920843907, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.01436675461741348, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.01486367634124678, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.01596306068601631, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.01616094986807148, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0174854881266482, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.018012313104663006, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.018243812036687672, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.018579595426559528, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.019050131926116647, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.01905013192612111, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.02110817941951547, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.021108179419526564, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.021773306948110027, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.022090369393131762, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.024350002094075, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0264127088830269, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.028051262721445827, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.038318947103894455, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.040224902625973814, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.04848284960421774, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0556300045887361, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.05746701846965752, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.057652814423923796, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.06438434476693226, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.06439669975290986, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.06804562445030626, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.07049820100743759, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.07299573826893915, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.07345734388742661, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.0786166382120056, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.08699230430957655, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.08808465968724732, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.09006156552331232, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.09562850517995597, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.10639182058048151, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.10731574318381647, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.10803946311804591, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.11755606860158382, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.1208368678953175, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.12380606860160223, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.1258894234914899, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.1418767654819172, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.14925693090129089, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.15302809250350596, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.1704349464920637, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.18181574318382587, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.26172464374359494, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.3166226912928754, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.3290347405452976, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.3785566013801184, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.4436115348167575, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.5025004958925221, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.5473219745534428, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.5486683763728405, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.565970286275362, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.6619126740761052, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.7292288812544807, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.7401354154717019, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.8767029463500231, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=0.9665105540897071, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=1.5524550208404841, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=2.7805629928629587, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=3.0571051999988947, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=4.661131420666424, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=5.281703754061629, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=17.06061074970865, random_state=0),
#  DecisionTreeRegressor(ccp_alpha=41.67185680975386, random_state=0)]

# %%
tree_depths = [clf.tree_.max_depth for clf in clfs]

plt.figure(figsize = (10, 6))
plt.plot(ccp_alphas[ : -1], tree_depths[ : -1])
plt.xlabel('effective alpha')
plt.ylabel('Profundidade de árvore')
# Out:
# Text(0, 0.5, 'Profundidade de árvore')

# %% [markdown]
# ### 4. Para cada árvore na lista, calcule o MSE da árvore.

# %%
mses = []
ind_i = []
ind_j = []

for i in range(2, 20):
    for j in range(2, 20):
        regr1 = DecisionTreeRegressor(max_depth = i, min_samples_leaf = j)
        regr1.fit(X_train, y_train)
        mse_1 = regr1.score(X_test, y_test)
        mses.append(mse_1)
        ind_i.append(i)
        ind_j.append(j)
        
        
plt.rc('figure', figsize = (15, 15))

df_mse = pd.DataFrame({'mses': mses, 'profundidade': ind_i, 'n_minimo': ind_j})
sns.heatmap(df_mse.pivot(index = 'profundidade', columns = 'n_minimo', values = 'mses'), annot = True, cmap = 'Reds')
df_mse.pivot(index = 'profundidade', columns = 'n_minimo', values = 'mses')
# Out:
# n_minimo            2         3         4         5         6         7   \
# profundidade
# 2             0.610035  0.610035  0.610035  0.610035  0.610035  0.610035
# 3             0.607844  0.608277  0.596417  0.625875  0.634217  0.645757
# 4             0.692832  0.672232  0.676667  0.627247  0.682184  0.665746
# 5             0.746096  0.728635  0.728312  0.681329  0.738481  0.717710
# 6             0.743498  0.732142  0.731462  0.664891  0.731649  0.722235
# 7             0.744630  0.729167  0.726462  0.664906  0.727585  0.722963
# 8             0.749006  0.724837  0.730650  0.676645  0.742202  0.735779
# 9             0.734383  0.709675  0.717384  0.668601  0.729093  0.729621
# 10            0.730816  0.700352  0.704882  0.666896  0.731378  0.731207
# 11            0.634854  0.692937  0.704831  0.665074  0.737778  0.731972
# 12            0.643058  0.699791  0.708316  0.665574  0.738948  0.731207
# 13            0.718118  0.699136  0.708781  0.667755  0.739713  0.731972
# 14            0.716784  0.704253  0.708716  0.665574  0.737013  0.731972
# 15            0.712844  0.700237  0.708096  0.665278  0.737778  0.731207
# 16            0.719568  0.697662  0.708092  0.667755  0.737013  0.731972
# 17            0.718533  0.701558  0.706419  0.666731  0.728867  0.731207
# 18            0.715563  0.698289  0.707626  0.667040  0.737778  0.731207
# 19            0.715694  0.692862  0.709822  0.665159  0.737013  0.731972
#
# n_minimo            8         9         10        11        12        13  \
# profundidade
# 2             0.610035  0.610035  0.610035  0.610035  0.610035  0.610035
# 3             0.645757  0.645757  0.645757  0.646825  0.647563  0.633841
# 4             0.658618  0.658618  0.658618  0.675995  0.672586  0.658864
# 5             0.710582  0.702706  0.702706  0.720175  0.720248  0.706526
# 6             0.717054  0.709117  0.707208  0.726767  0.723949  0.710372
# 7             0.718808  0.705538  0.710841  0.732575  0.727482  0.714202
# 8             0.722554  0.708404  0.714100  0.736191  0.730508  0.716231
# 9             0.721596  0.706656  0.713639  0.735729  0.730277  0.716231
# 10            0.721596  0.706656  0.713639  0.735729  0.730277  0.716231
# 11            0.721596  0.706656  0.713639  0.735729  0.730277  0.716231
# 12            0.721596  0.706656  0.713639  0.735729  0.730277  0.716231
# 13            0.721596  0.706656  0.713639  0.735729  0.730277  0.716231
# 14            0.721596  0.706656  0.713639  0.735729  0.730277  0.716231
# 15            0.721596  0.706656  0.713639  0.735729  0.730277  0.716231
# 16            0.721596  0.706656  0.713639  0.735729  0.730277  0.716231
# 17            0.721596  0.706656  0.713639  0.735729  0.730277  0.716231
# 18            0.721596  0.706656  0.713639  0.735729  0.730277  0.716231
# 19            0.721596  0.706656  0.713639  0.735729  0.730277  0.716231
#
# n_minimo            14        15        16        17        18        19
# profundidade
# 2             0.610035  0.610035  0.610035  0.610035  0.610035  0.610035
# 3             0.633841  0.633841  0.633841  0.633841  0.633841  0.633841
# 4             0.658864  0.658864  0.658864  0.658864  0.656773  0.656773
# 5             0.703893  0.703893  0.703161  0.704923  0.704621  0.700095
# 6             0.710287  0.710532  0.705662  0.707847  0.707545  0.701806
# 7             0.711122  0.713465  0.708857  0.709954  0.709652  0.703913
# 8             0.713286  0.713465  0.708857  0.709954  0.709652  0.703913
# 9             0.713286  0.713465  0.708857  0.709954  0.709652  0.703913
# 10            0.713286  0.713465  0.708857  0.709954  0.709652  0.703913
# 11            0.713286  0.713465  0.708857  0.709954  0.709652  0.703913
# 12            0.713286  0.713465  0.708857  0.709954  0.709652  0.703913
# 13            0.713286  0.713465  0.708857  0.709954  0.709652  0.703913
# 14            0.713286  0.713465  0.708857  0.709954  0.709652  0.703913
# 15            0.713286  0.713465  0.708857  0.709954  0.709652  0.703913
# 16            0.713286  0.713465  0.708857  0.709954  0.709652  0.703913
# 17            0.713286  0.713465  0.708857  0.709954  0.709652  0.703913
# 18            0.713286  0.713465  0.708857  0.709954  0.709652  0.703913
# 19            0.713286  0.713465  0.708857  0.709954  0.709652  0.703913

# %% [markdown]
# ### 5. Monte um gráfico do MSE pelo alpha, escolha um valor de alpha perto do ponto de mínimo do MSE

# %%
train_scores = [mean_squared_error(y_train , clf.predict(X_train)) for clf in clfs]
test_scores  = [mean_squared_error(y_test  , clf.predict(X_test )) for clf in clfs]

fig, ax = plt.subplots()
ax.set_xlabel("alpha")
ax.set_ylabel("MSE")
ax.set_title("MSE x alpha do conjunto de dados de treino e teste")
ax.plot(ccp_alphas[:-1], train_scores[:-1], marker='o', label="treino",
        drawstyle="steps-post")
ax.plot(ccp_alphas[:-1], test_scores[:-1], marker='o', label="teste",
        drawstyle="steps-post")
ax.legend()
plt.show()

# %% [markdown]
# ### 6. Calcule o R-quadrado dessa árvore encontrada no item acima

# %%
arvore_final = DecisionTreeRegressor(random_state = 0, ccp_alpha = 2.5)
arvore_final.fit(X_train, y_train)

print(f"Profundidade: {arvore_final.tree_.max_depth}")
print(f"R-quadrado na base de testes: {arvore_final.score(X_test, y_test):.2f}")
print(f"MSE na base de testes: {mean_squared_error(y_test, arvore_final.predict(X_test)):.2f}")

# alpha 2.5 parece ser o valor que gera R-quadrado mais elevado e MSE mais baixo, mesmo com maior profundidade da árvore.
# Out:
# Profundidade: 4
# R-quadrado na base de testes: 0.67
# MSE na base de testes: 22.70

# %% [markdown]
# ### 7. Visualize esta árvore.

# %%
plt.rc('figure', figsize = (15, 15))
tp = tree.plot_tree(arvore_final,
                   feature_names = X.columns,
                   filled = True)
